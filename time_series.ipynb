# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sklearn

# %%
N = 600

t = np.arange(0, N, 1).reshape(-1, 1)
t = np.array([t[i] + np.random.rand(1)/4 for i in range(len(t))])
t = np.array([t[i] - np.random.rand(1)/7 for i in range(len(t))])
t = np.array(np.round(t, 2))

x1 = np.round((np.random.random(N) * 5).reshape(-1, 1), 2)
x2 = np.round((np.random.random(N) * 5).reshape(-1, 1), 2)
x3 = np.round((np.random.random(N) * 5).reshape(-1, 1), 2)

n = np.round((np.random.random(N) * 2).reshape(-1, 1), 2)

y = np.array([((np.log(np.abs(2 + x1[t])) - x2[t-1]**2) + 0.02*x3[t-3]*np.exp(x1[t-1])) for t in range(len(t))])
y = np.round(y+n, 2)

# %%
# N = 600

# t = np.arange(0, N, 1).reshape(-1,1)
# t = np.array([t[i] + np.random.rand(1)/4 for i in range(len(t))])
# t = np.array([t[i] - np.random.rand(1)/7 for i in range(len(t))])
# t = np.array(np.round(t, 2))

# x1 = np.round((np.random.random(N) * 5).reshape(-1,1), 2)
# x2 = np.round((np.random.random(N) * 5).reshape(-1,1), 2)
# x3 = np.round((np.random.random(N) * 5).reshape(-1,1), 2)

# n = np.round((np.random.random(N) * 2).reshape(-1,1), 2)

# y = np.array([((np.log(np.abs(2 + x1[t])) - x2[t-1]**2) + 0.02*x3[t-3]*np.exp(x1[t-1])) for t in range(len(t))])
# y = np.round(y+n, 2)

# %%
plt.plot(t, y)
plt.show()

# %%
dataset = pd.DataFrame(np.concatenate((t, x1, x2, x3, y), axis=1), columns=['t', 'x1', 'x2', 'x3', 'y'])

deltaT = np.array([dataset.t[i + 1] - dataset.t[i] for i in range(len(dataset.t) - 1)])
deltaT = np.concatenate((np.array([0]), deltaT))

dataset.insert(1, 'deltaT', deltaT)
dataset.head(3)
# Out:
#       t  deltaT    x1    x2    x3      y
# 0  0.06    0.00  0.28  1.45  2.75   1.57
# 1  1.00    0.94  0.17  4.04  3.73  -0.15
# 2  2.14    1.14  0.39  0.48  0.41 -14.74

# %%
# dataset = pd.DataFrame(np.concatenate((t, x1, x2, x3, y), axis=1), 
#                        columns=['t', 'x1', 'x2', 'x3', 'y'])

# deltaT = np.array([(dataset.t[i + 1] - dataset.t[i]) for i in range(len(dataset)-1)])
# deltaT = np.concatenate((np.array([0]), deltaT))

# dataset.insert(1, '∆t', deltaT)
# dataset.head(3)

# %%
w = 5
train_constructor = WindowSlider()
train_windows = train_constructor.collect_windows(trainset.iloc[:,1:], 
                                                  previous_y=False)

test_constructor = WindowSlider()
test_windows = test_constructor.collect_windows(testset.iloc[:,1:],
                                                previous_y=False)

train_constructor_y_inc = WindowSlider()
train_windows_y_inc = train_constructor_y_inc.collect_windows(trainset.iloc[:,1:], 
                                                  previous_y=True)

test_constructor_y_inc = WindowSlider()
test_windows_y_inc = test_constructor_y_inc.collect_windows(testset.iloc[:,1:],
                                                previous_y=True)

train_windows.head(3)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\zfenton\Desktop\VSC files\MLProject\time_series.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zfenton/Desktop/VSC%20files/MLProject/time_series.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> import sktime
#
# ModuleNotFoundError: No module named 'sktime'

# %%
pip list
# Out:
# Package              Version
# -------------------- -----------
# anyio                3.6.1
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                22.1.0
# Babel                2.11.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.1
# bokeh                2.4.3
# certifi              2022.9.24
# cffi                 1.15.1
# charset-normalizer   2.1.1
# colorama             0.4.5
# colorcet             3.0.1
# contourpy            1.0.6
# cycler               0.11.0
# debugpy              1.6.2
# decorator            5.1.1
# defusedxml           0.7.1
# Deprecated           1.2.13
# entrypoints          0.4
# executing            0.8.3
# fastjsonschema       2.16.2
# fonttools            4.38.0
# holoviews            1.15.3
# hvplot               0.8.2
# idna                 3.4
# ipykernel            6.15.1
# ipython              8.4.0
# ipython-genutils     0.2.0
# ipywidgets           8.0.2
# jedi                 0.18.1
# Jinja2               3.1.2
# joblib               1.2.0
# json5                0.9.10
# jsonschema           4.17.3
# jupyter              1.0.0
# jupyter-client       7.3.4
# jupyter-console      6.4.4
# jupyter-core         4.11.1
# jupyter-server       1.21.0
# jupyterlab           3.5.2
# jupyterlab-pygments  0.2.2
# jupyterlab_server    2.17.0
# jupyterlab-widgets   3.0.3
# kiwisolver           1.4.4
# llvmlite             0.39.1
# Markdown             3.4.1
# MarkupSafe           2.1.1
# matplotlib           3.6.2
# matplotlib-inline    0.1.3
# mistune              2.0.4
# nbclassic            0.4.5
# nbclient             0.7.0
# nbconvert            7.2.1
# nbformat             5.7.0
# nest-asyncio         1.5.5
# notebook             6.5.1
# notebook-shim        0.1.0
# numba                0.56.4
# numpy                1.23.1
# packaging            21.3
# panda                0.3.1
# pandas               1.4.3
# pandocfilters        1.5.0
# panel                0.14.2
# param                1.12.3
# parso                0.8.3
# patsy                0.5.3
# pickleshare          0.7.5
# Pillow               9.3.0
# pip                  22.3.1
# prometheus-client    0.15.0
# prompt-toolkit       3.0.30
# psutil               5.9.1
# pure-eval            0.2.2
# pycparser            2.21
# pyct                 0.4.8
# Pygments             2.12.0
# pyparsing            3.0.9
# pyrsistent           0.18.1
# python-dateutil      2.8.2
# pytz                 2022.1
# pyviz-comms          2.2.1
# pywin32              304
# pywinpty             2.0.8
# PyYAML               6.0
# pyzmq                23.2.0
# qtconsole            5.3.2
# QtPy                 2.2.1
# requests             2.28.1
# scikit-learn         1.1.2
# scipy                1.9.1
# Send2Trash           1.8.0
# setuptools           58.1.0
# six                  1.16.0
# sklearn              0.0
# sktime               0.15.0
# sniffio              1.3.0
# soupsieve            2.3.2.post1
# stack-data           0.3.0
# statsmodels          0.13.5
# terminado            0.16.0
# threadpoolctl        3.1.0
# tinycss2             1.1.1
# tomli                2.0.1
# tornado              6.2
# tqdm                 4.64.1
# traitlets            5.3.0
# typing_extensions    4.4.0
# urllib3              1.26.13
# wcwidth              0.2.5
# webencodings         0.5.1
# websocket-client     1.4.1
# widgetsnbextension   4.0.3
# wrapt                1.14.1
# Note: you may need to restart the kernel to use updated packages.
